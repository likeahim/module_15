# %%
import pandas as pd
names_series = pd.Series(["Mark", "John", "Daniel", "Greg"])
names_series
salary_series = pd.Series([1000, 1500, 2300, 5000])
salary_series
names_series.describe()
salary_series.describe()
salary_series.index
salary_series.index = names_series
salary_series
salary_series['Mark']
names = ["Mark", "John", "Daniel", "Greg"]
salaries = [1000, 1500, 2300, 5000]
salary_series_improved = pd.Series(salaries, index=names)
salary_series_improved
# Out:
# Mark      1000
# John      1500
# Daniel    2300
# Greg      5000
# dtype: int64

# %%
salaries = [
	("Mark", 1000, 23),
	("John", 1500, 25),
	("Daniel", 2300, 38),
	("Greg", 5000, 42)
]
df = pd.DataFrame(salaries, columns=["name", "salary", "age"])
df = df.set_index("name")
salary_increased_series = df['salary'].apply(lambda salary: salary + 2000)
df['salary'] = salary_increased_series
salary_increased_series

# Tworzenie DataFrame
df = pd.DataFrame(salaries, columns=["name", "salary", "age"])

# Dodanie kolumny z inicjałem imienia
df["initials"] = df["name"].str[0]

# Wyświetlenie DataFrame
print(df)

df['salary'].plot(kind='bar')
# Out:
#      name  salary  age initials
# 0    Mark    1000   23        M
# 1    John    1500   25        J
# 2  Daniel    2300   38        D
# 3    Greg    5000   42        G
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 22
#      19 # Wyświetlenie DataFrame
#      20 print(df)
# ---> 22 df['salary'].plot(kind='bar')
#
# File ~/IdeaProjects/dev/py/module_15/venv/lib/python3.10/site-packages/pandas/plotting/_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# File ~/IdeaProjects/dev/py/module_15/venv/lib/python3.10/site-packages/pandas/plotting/_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File ~/IdeaProjects/dev/py/module_15/venv/lib/python3.10/site-packages/pandas/plotting/_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
